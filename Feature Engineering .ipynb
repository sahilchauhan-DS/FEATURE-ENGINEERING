# %% [markdown]
# 1.  What is a parameter?
#
# Ans: A parameter is a variable in a model that is learned from trained data.
#
# 2. What is correlation?
#  What does negative correlation mean?
#
# Ans:Correlation measures the strength and direction of a linear relationship betweeen two variables.
#
# negative correlation means that as one variable increases the other decreases.
#
#
# 3.  Define Machine Learning. What are the main components in Machine Learning?
#
# Ans: Machine learing means systems learning patterns from the data . components: data , model , loss function etc...
#
# 4.  How does loss value help in determining whether the model is good or not?
#
# Ans: A low loss value indicates better model performance.
#
# 5.  What are continuous and categorical variables?
#
# Ans: Continuous means numerical values and categorical means string values.
#
# 6. How do we handle categorical variables in Machine Learning? What are the common techniques?
#
# Ans:we will convert the cathegorical data into numerical data. One- Hot Encoding , label Encoding.
#
# 7.  What do you mean by training and testing a dataset?
#
# Ans:  training means learning the models from the data and testing means evaluating the unseen data.
#
# 8.  What is sklearn.preprocessing?
#
# Ans: A module in scikit-learn for preprocessing data like scaling and encoding.
#
# 9.  What is a Test set?
#
# Ans:  A subset of data used to evaluate the model after training.
#
# 10. How do we split data for model fitting (training and testing) in Python?
#  How do you approach a Machine Learning problem?
#
# Ans: Use train_test_split() from sklearn.model_selection.
# Define problem , gather data , preprocess , model , evaluate , deploy.
#
# 11. Why do we have to perform EDA before fitting a model to the data?
#
# Ans:  To understand data patterns, detect outliers and choose features.
#
# 12. What is correlation?
#
# Ans: It is used to find the strenght and direction between two relational varaibles.
#
# 13. What does negative correlation mean?
#
# Ans: IF one variable increases another variable is decreases is an negative correlation.
#
# 14. How can you find correlation between variables in Python?
#
# Ans: Using np.corr() or sns.heatmap()
#
#
# 15. What is causation? Explain difference between correlation and causation with an example?
#
# Ans: causation means one variable causes another.
#
# Correlation menas finding the relation between two variables.
#
# 16. What is an Optimizer? What are different types of optimizers? Explain each with an example.?
#
# Ans:  Optimizers adjust weights to minimize loss.
# Types: GD, SGD, Adam , RMSprop.
# 1. GD: (Gradiant Descent): Updates weighrs in the opposite direction of the gradient of the loss.
# 2. SGD-(Stochastic gradient descent): Using one random sample at a time.
# 3. ADAM - (Adaptive Moment Estimation): Combines momentum and RMSprop .
# 4. RMSprop: Adapts learning rate using a moving average of squared gradients.
#
# 17. What is sklearn.linear_model ?
#
# Ans: A module with linear models like LinearRegression and logisticRegression.
#
# 18. What does model.fit() do? What arguments must be given?
#
# Ans: Trains the model on data . it needs features and labels.
#
# 19. What does model.predict() do? What arguments must be given?
#
# Ans: Makes predictions on new data. Needs input features.
#
# 20. What are continuous and categorical variables?
#
# Ans: Continuous means numerical values eg: 1,2 ,10, 45.3 etc and categorical means string values eg: Hi , Bangalore , First etc...
#
# 21. What is feature scaling? How does it help in Machine Learning?
#
# Ans: Rescales features to a common scale. Helps models converge faster.
#
# 22. How do we perform scaling in Python?
#
# Ans: using StandardScaler or MinMaxScaler from sklearn.preprocessing.
#
# 23. What is sklearn.preprocessing?
#
# Ans:A module in scikit-learn for preprocessing data like scaling and encodi
#
# 24. How do we split data for model fitting (training and testing) in Python?
#
# Ans:Use train_test_split() from sklearn.model_selection.
#
# 25. Explain data encoding?
#
# Ans: It converts cathegorical data into numerical data.
# eg: One- hot encoding ,Label encoding
